# %% [markdown]
# # 🐍 Task 2: Basic Concepts of Python
#
# ## Topics
# - How Python Works
# - Running Python Scripts
# - Python Interpreter
# - REPL
# - Indentation
# - Syntax Rules
# - Standard Code Practices
# - PEP 8

# %% [markdown]
# ## How Python Works
#
# Python Source Code (.py)
# → Python Interpreter
# → Bytecode (.pyc)
# → Python Virtual Machine (PVM)
# → Output

# %%
print("Hello, Python!")

# %% [markdown]
# ## Running Python Scripts
# Save as `hello.py` and run:
# ```bash
# python3 hello.py
# ```

# %% [markdown]
# ## Python Interpreter
# The interpreter reads and executes code line by line.

# %%
a = 10
b = 20
print("Sum =", a + b)

# %% [markdown]
# ## REPL
# Start REPL using `python3` in Terminal.

# %% [markdown]
# ## Indentation

# %%
age = 20

if age >= 18:
    print("Adult")
else:
    print("Minor")

# %% [markdown]
# ## Syntax Rules
# - Case-sensitive
# - Quotes for strings
# - Comments start with `#`

# %%
# This is a comment
name = "Mayur"
print(name)

# %% [markdown]
# ## Standard Code Practices
# - Meaningful names
# - 4-space indentation
# - Keep code readable

# %%
student_name = "Mayur"
total_marks = 92

print(student_name)
print(total_marks)

# %% [markdown]
# ## PEP 8
# - snake_case for variables/functions
# - PascalCase for classes
# - UPPER_CASE for constants
# - Spaces around operators

# %%
MAX_MARKS = 100

student_name = "Mayur"
marks = 95

if marks >= 35:
    print("Pass")

# %% [markdown]
# ## Practice Exercise

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print(f"Hello {name}")

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible")
