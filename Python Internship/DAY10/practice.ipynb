# %%
text = "Python" 
print(text[::-1])
# Out:
# nohtyP

# %%
text = "madam" 
print(text == text[::-1])
# Out:
# True

# %%
n = 5
fact = 1
for i in range(1, n+5):
    fact*=i
print(fact)
# Out:
# 362880

# %%
a, b = 0, 1 
for _ in range(5): 
    print(a, end=" ") 
    a, b = b, a + b
# Out:
# 0 1 1 2 3
