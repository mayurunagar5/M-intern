# %% [markdown]
# # Task 3 Python Chapter — Lists
#
# ## 1. Overview
#
# A **List** is an **ordered**, **mutable**, and **dynamic** collection of objects. It is one of the most commonly used data structures in Python because it can store multiple values of different data types and can grow or shrink dynamically.
#
# Lists are extensively used in:
#
# - Data Processing
# - Machine Learning
# - Web Development
# - Automation
# - APIs
# - Data Structures & Algorithms
#
# ---
#
# # 2. Theory
#
# ## Characteristics
#
# - Ordered
# - Mutable
# - Dynamic Size
# - Allows Duplicate Values
# - Supports Mixed Data Types
# - Supports Indexing & Slicing
# - Iterable
#
# Example
#
# ```python
# numbers = [10, 20, 30]
# ```
#
# ---
# ## Internal Working
#
# Python implements a list as a **Dynamic Array**.
#
# ```
# Index
#
# 0    1    2    3
#
# +----+----+----+----+
# |10  |20  |30  |    |
# +----+----+----+----+
# ```
#
# Python allocates extra memory so that `append()` usually doesn't require allocating a new array every time.
#
# When capacity is full:
#
# ```
# Old Array
# +----+----+----+
# |10  |20  |30  |
# +----+----+----+
#
#         │
#
#         ▼
#
# New Larger Array
#
# +----+----+----+----+----+----+
# |10  |20  |30  |40  |    |    |
# +----+----+----+----+----+----+
# ```
#
# This is why `append()` is **O(1) amortized** instead of always O(1).
#
# ---
#
# ## Memory Note
#
# ```python
# a = [1,2,3]
# b = a
# ```
#
# ```
# a ─┐
#    │
#    ▼
# +---------+
# |1|2|3|
# +---------+
#    ▲
#    │
# b ─┘
# ```
#
# Both variables point to the same list.
#
# ---
#
# # 3. Creating Lists
#
# ```python
# numbers = [1,2,3]
#
# numbers = list((1,2,3))
#
# chars = list("Python")
# ```
#
# ---
#
# # 4. Operations
#
# ## Indexing
#
# ```python
# numbers[0]
#
# numbers[-1]
# ```
#
# ---
#
# ## Slicing
#
# ```python
# numbers[1:4]
#
# numbers[:3]
#
# numbers[2:]
#
# numbers[::-1]
# ```
#
# ---
#
# ## Operators
#
# ### Concatenation
#
# ```python
# [1,2] + [3,4]
# ```
#
# ---
#
# ### Repetition
#
# ```python
# [1] * 5
# ```
#
# ---
#
# ### Membership
#
# ```python
# 20 in numbers
# ```
#
# ---

# %%
numbers=[1,2,3,4,5]
print(numbers)


#slicing

numbers = [10, 20, 30, 40, 50]

print(numbers[1:4])
print(numbers[:3])
print(numbers[2:])
print(numbers[::-1])
# Out:
# [1, 2, 3, 4, 5]
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]
# [50, 40, 30, 20, 10]

# %%
#Concatenation

list1 = [1, 2]
list2 = [3, 4]

result = list1 + list2
print(result)
# Out:
# [1, 2, 3, 4]

# %%
fruits = ["Apple", "Banana", "Mango"]

print("Applee" in fruits)
print("Orange" not in fruits)
# Out:
# False
# True

# %%
 # Updating list 

fruits = ["Apple", "Banana", "Mango"]

fruits[1]= "grapes"
print(fruits)
# Out:
# ['Apple', 'grapes', 'Mango']

# %%
#delet list

num= [1,2,3,4,5,6,7]
del num[3]
print(num)
# Out:
# [1, 2, 3, 5, 6, 7]

# %%
num= [1,2,3,4,5,6,7]
for n in num:
    print(n)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
fruits = ["Apple", "Banana", "Mango"]

for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Banana
# Mango

# %%
matrix = [
    [1, 2],
    [3, 4]
]

print(matrix[0])
print(matrix[1][1])
# Out:
# [1, 2]
# 4

# %% [markdown]
# # 5. Built-in Functions
#
# | Function | Purpose |
# |----------|----------|
# | `len()` | Length |
# | `min()` | Smallest element |
# | `max()` | Largest element |
# | `sum()` | Sum of numeric values |
# | `sorted()` | Returns a sorted copy |
#
# ---
#
# # 6. List Methods
#
# | Method | Purpose | Syntax | Example | Returns | Modifies Original | Complexity |
# |---------|---------|--------|---------|----------|:-----------------:|------------|
# | `append()` | Add one item | `lst.append(x)` | `[1,2].append(3)` → `[1,2,3]` | `None` | ✅ | O(1) amortized |
# | `extend()` | Add iterable | `lst.extend(it)` | `[1,2].extend([3,4])` → `[1,2,3,4]` | `None` | ✅ | O(k) |
# | `insert()` | Insert at index | `lst.insert(i,x)` | `[1,3].insert(1,2)` → `[1,2,3]` | `None` | ✅ | O(n) |
# | `remove()` | Remove first matching value | `lst.remove(x)` | `[1,2,2].remove(2)` → `[1,2]` | `None` | ✅ | O(n) |
# | `pop()` | Remove by index | `lst.pop(i)` | `[1,2,3].pop()` → `3` | Removed Item | ✅ | O(1)/O(n) |
# | `clear()` | Remove all items | `lst.clear()` | `[1,2].clear()` → `[]` | `None` | ✅ | O(n) |
# | `copy()` | Shallow copy | `lst.copy()` | `b=a.copy()` | `list` | ❌ | O(n) |
# | `index()` | Find first occurrence | `lst.index(x)` | `[10,20].index(20)` → `1` | `int` | ❌ | O(n) |
# | `count()` | Count occurrences | `lst.count(x)` | `[1,1,2].count(1)` → `2` | `int` | ❌ | O(n) |
# | `reverse()` | Reverse list | `lst.reverse()` | `[1,2,3]` → `[3,2,1]` | `None` | ✅ | O(n) |
# | `sort()` | Sort list | `lst.sort()` | `[3,1,2]` → `[1,2,3]` | `None` | ✅ | O(n log n) |
# | `sorted()`* | Sorted copy | `sorted(lst)` | `sorted([3,1,2])` → `[1,2,3]` | `list` | ❌ | O(n log n) |
#
# > **Note:** `sorted()` is a built-in function, not a list method.
#
# ---

# %%
#1. append() - Add a single element at the end

fruits = ["Apple", "Banana"]

fruits.append("Mango")

print(fruits)
# Out:
# ['Apple', 'Banana', 'Mango']

# %%
#2. extend()
fruits = ["Apple", "Banana"]

fruits.extend(["Mango", "Orange"])

print(fruits)
# Out:
# ['Apple', 'Banana', 'Mango', 'Orange']

# %%
# 3. insert() - Insert an element at a specific index

fruits = ["banana", "mango"]
fruits.insert(1, "orange")
print(fruits)
# Out:
# ['banana', 'orange', 'mango']

# %%
# 4. remove() - Remove the first matching 

fruits = ["orange", "mango", "apple"]
fruits.remove("mango")
print(fruits)
# Out:
# ['orange', 'apple']

# %%
# 5. pop() - Remove and return the last element

students = ["mayur","vinit","vatsal", "harsh"]
result = students.pop()
print(result)
print(students)

# Remove using index

result1 = students.pop(1)

print(result1)
# Out:
# harsh
# ['mayur', 'vinit', 'vatsal']
# vinit

# %%
# 6. clear() - Remove all elements

students = ["m", "v", "h", "d"]
result = students.clear()
print(result)
# Out:
# None

# %%
# 7. index() - Find the position of an element

students = ["m", "v", "h", "d"]
result = students.index("h")
print(result)
# Out:
# 2

# %%
# 8. count() - Count occurrences

students = ["m", "v", "h", "d"]
result = students.count("m")
print(result)
# Out:
# 1

# %%
# 9. sort() - Sort in ascending order

count = [30,20,70,40]
count.sort()
print(count)
# Out:
# [20, 30, 40, 70]

# %%
# 10. reverse() - Reverse the list

numbers = [10, 20, 30, 40]

numbers.reverse()

print(numbers)
# Out:
# [40, 30, 20, 10]

# %%
# 11. copy() - Create a shallow copy

fruits = ["Apple", "Banana", "Mango"]

new_fruits = fruits.copy()

print(new_fruits)
# Out:
# ['Apple', 'Banana', 'Mango']

# %% [markdown]
# Key Takeaways
#
# - Lists are mutable dynamic arrays with fast indexing.
# - `append()` is usually O(1) because Python overallocates memory.
# - Choose `append()`, `extend()`, `sort()`, and `sorted()` based on whether you want to modify the original list.
# - Understand shallow copies and reference behavior to avoid subtle bugs.
# - Lists are one of the most fundamental data structures in Python and are used extensively in AI, data analysis, automation, and general software development.
