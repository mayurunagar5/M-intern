# %% [markdown]
# # Task 3: Python Operators, Input/Output & Type Casting
# Comprehensive notebook with explanations and examples.

# %% [markdown]
# ## Arithmetic Operators
# Explanation and example.

# %%
a=10
b=3
print(a+b,a-b,a*b,a/b,a//b,a%b,a**b)
# Out:
# 13 7 30 3.3333333333333335 3 1 1000

# %% [markdown]
# ## Assignment Operators
# Explanation and example.

# %%
x=10
x+=5
print(x)
x*=2
print(x)
# Out:
# 15
# 30

# %% [markdown]
# ## Comparison Operators
# Explanation and example.

# %%
a=10
b=20
print(a==b,a!=b,a<b,a>=b)
# Out:
# False True True False

# %% [markdown]
# ## Logical Operators
# Explanation and example.

# %%
age=20
citizen=True
print(age>=18 and citizen)
print(age<18 or citizen)
print(not citizen)
# Out:
# True
# True
# False

# %% [markdown]
# ## Bitwise Operators
# Explanation and example.

# %%
a=5
b=3
print(a&b,a|b,a^b,~a,a<<1,a>>1)
# Out:
# 1 7 6 -6 10 2

# %% [markdown]
# ## Membership Operators
# Explanation and example.

# %%
fruits=['Apple','Banana']
print('Apple' in fruits)
print('Orange' not in fruits)
# Out:
# True
# True

# %% [markdown]
# ## Identity Operators
# Explanation and example.

# %%
a=[1,2]
b=a
c=[1,2]
print(a is b)
print(a is c)
# Out:
# True
# False

# %% [markdown]
# ## Input and Output
# Explanation and example.

# %%
name='Mayur' # replace with input('Name: ')
print(f'Hello {name}')
# Out:
# Hello Mayur

# %% [markdown]
# ## Type Casting
# Explanation and example.

# %%
age='20'
print(int(age)+5)
print(float('2.5'))
print(str(100))
print(bool(1), bool(0))
# Out:
# 25
# 2.5
# 100
# True False

# %% [markdown]
# ## Implicit vs Explicit
# Explanation and example.

# %%
a=10
b=2.5
print(a+b)
print(int('50'))
# Out:
# 12.5
# 50

# %% [markdown]
# ## Mini Calculator
# Explanation and example.

# %%
a=15
b=5
print('Add',a+b)
print('Sub',a-b)
print('Mul',a*b)
print('Div',a/b)
# Out:
# Add 20
# Sub 10
# Mul 75
# Div 3.0

# %% [markdown]
# ## Practice Exercises
# 1. Calculator
# 2. Voting eligibility
# 3. Even/Odd
# 4. Temperature converter
# 5. Swap two numbers

# %%
text = "python"
print(text[-1])
# Out:
# n
